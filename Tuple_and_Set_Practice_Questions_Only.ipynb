# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
# write your answer here
tup1=(1,5,6,7,9)
print(tup1)
# Out:
# (1, 5, 6, 7, 9)

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
# write your answer here
tup2=(10,10.5,"string",True)
print(tup2[0],tup2[1],tup2[2],tup2[3])
# Out:
# 10 10.5 string True

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
# write your answer here
students_name=("cheeku","aashita","rohit","ram")
print("length of tuple:",len(students_name))
# Out:
# length of tuple: 4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
# write your answer here
students_name=("cheeku","aashita","rohit","ram")
print(students_name[-1])
# Out:
# ram

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
# write your answer here
students_name=("cheeku","aashita","rohit","ram")
"ram" in students_name
# Out:
# True

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
# write your answer here
t= (1,3,54,4,5,4,)
list1= list(t)
print(list1)
# Out:
# [1, 3, 54, 4, 5, 4]

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
# write your answer here
list1= [1,2,5,6,70]
t = tuple(list1)
print(t)
# Out:
# (1, 2, 5, 6, 70)

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
# write your answer here
t= (2,2,3,6,4,7,2,9,8,9,5,10)
for i in t:
  print(t.count(i), end="")
# Out:
# 331111321211

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
# write your answer here
t= (2,2,3,6,4,7,2,9,8,9,5,10)
print(t.index(9))
# Out:
# 7

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
# write your answer here
t = (1,2,3,5,4,10)
t[1]=200 # this line gives an error which shows 'tuple' object does not support item assignment

print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2023450682.py in <cell line: 0>()
#       1 # write your answer here
#       2 t = (1,2,3,5,4,10)
# ----> 3 t[1]=200
#       4 print(t)
#
# TypeError: 'tuple' object does not support item assignment
